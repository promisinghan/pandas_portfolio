# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale portfolio Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Check my current directory
print(f"My current path is---> {Path.cwd()}")
# Out:
# My current path is---> C:\Users\Minyeong\desktop\pandas_portfolio

# %%
# Reading whale returns
whale_returns_csv = Path("whale_returns.csv")
whale_df = pd.read_csv(whale_returns_csv)
whale_df.head(3)
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213

# %%
# Setting index into Date column and converting the dates to a DateTimeIndex
whale_df.set_index(pd.to_datetime(whale_df['Date'], infer_datetime_format=True), inplace=True)
whale_df.head(3)
# Out:
#                   Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02  2015-03-02                        NaN                 NaN
# 2015-03-03  2015-03-03                  -0.001266           -0.004981
# 2015-03-04  2015-03-04                   0.002230            0.003241
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213

# %%
# Drop extra column
whale_df.drop(columns=['Date'], inplace=True)
whale_df.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213

# %%
# Sort datetime index in ascending order (past to present)
whale_df.sort_index(inplace=True)
whale_df.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)

# %%
# Sanity check
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Sanity check
whale_df.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("algo_returns.csv")
algo_df = pd.read_csv(algo_returns_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_df.sort_index(inplace=True)
algo_df.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)

# %%
# Sanity check
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# Sanity check
algo_df.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# 2014-06-12 -0.000028 -0.003841
# 2014-06-13  0.001917 -0.000814
# 2014-06-16  0.001084  0.001831
# 2014-06-17  0.000922  0.006870
# 2014-06-18 -0.006303  0.007228

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("sp500_history.csv")

sp500_df = pd.read_csv(sp500_history_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_df.sort_index(inplace=True)
sp500_df.head(3)
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types. Remove dollar signs from "Close" column and convert the data types as numeric values.
sp500_df["Close"] = sp500_df["Close"].str.replace("$", " ").astype("float")

# %%
# Sanity check
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Sanity check
sp500_df.head(3)
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99

# %%
# Calculate Daily Returns
sp500_df = sp500_df.pct_change()
sp500_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Count nulls
sp500_df.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
# Drop nulls
sp500_df.dropna(inplace=True)
sp500_df.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column
sp500_df.rename(columns={"Close": "S&P 500"}, inplace=True)
sp500_df.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat([whale_df, algo_df, sp500_df], axis="columns", join="inner")
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %%
# Sort datetime index in ascending order (past to present)
combined_df.sort_index(inplace=True)

# Display a few rows for sanity check
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
combined_df.plot(title = "Daily Returns", figsize = (20, 7))

# %%
# Plot cumulative returns
cumulative_returns = ( 1 + combined_df ).cumprod() 
cumulative_returns.plot(title = "Cumulative Returns", figsize = (20, 7))

# %% [markdown]
# - Qeustion: Does any portfolio outperform the S&P 500?
# <br>
# <br>
# - Answer: Based on the plot above, I think BERKSHIRE HATHAWAY INC. from the Whales portfolio and Algo 1 from Harold's company outperform the S&P 500.

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
combined_df.plot.box(title = "Portfolio Risk", figsize = (20, 7))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
volatility = combined_df.std()
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Which portfolios are riskier than the S&P 500?
# Determine which portfolios are riskier than the S&P 500
volatility > volatility["S&P 500"]
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %% [markdown]
# - Answer: Based on above, TIGER GLOBAL MANAGEMENT LLC and BERKSHIRE HATHAWAY INC from Whale portfolio have higher standard deviation than S&P 500's standard deviation, so I conclude that they are riskier than the S&P 500.

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_volatility = combined_df.std() * np.sqrt(252)
annualized_volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
# YOUR CODE HERE
rolling_std_21 = combined_df.rolling(window=21).std().plot(title = "21 Day Rolling Standard Deviation", figsize = (20, 7))

# %%
# Construct a correlation table
correlation = combined_df.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Plot correlations
sns.heatmap(correlation, vmin=-1, vmax=1)

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
covariance = combined_df["BERKSHIRE HATHAWAY INC"].rolling(window=60).cov(combined_df["S&P 500"])
variance = combined_df["S&P 500"].rolling(window=60).var()
beta = covariance / variance
beta.plot(figsize=(20,7), title = "Rolling 60-Day Beta of BERKSHIRE HATHAWAY INC")

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
ewm_std = combined_df.ewm(halflife = 21).std()
ewm_std.plot(figsize = (20,7))

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
combined_return = combined_df.mean() * 252
combined_risk = combined_df.std() * np.sqrt(252)
sharpe_ratios = combined_return / combined_risk
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar()

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:
#
# - Answer: Yes, the Algo1 outperforms both 'the market(S&P 500)' and the whales. Algo 2, however, outperforms most of whales porfotlios which include SOROS FUND MANAGEMENT LLC, PAULSON & CO INC, TIGER GLOBAL MANAGEMENT LLC, but it does not perform better than 'the market(S&P 500)'. Overall, the algorithmic trading portfolios are doing well compared to the market and whales portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
wmt_history_csv = Path("wmt_historical.csv")

wmt_df = pd.read_csv(wmt_history_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
wmt_df.sort_index(inplace=True)
wmt_df.head(3)
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  85.90
# 2015-01-05 16:00:00  85.65
# 2015-01-06 16:00:00  86.31

# %%
# Read the second stock
fb_history_csv = Path("fb_historical.csv")

fb_df = pd.read_csv(fb_history_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
fb_df.sort_index(inplace=True)
fb_df.head(3)
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  78.45
# 2015-01-05 16:00:00  77.19
# 2015-01-06 16:00:00  76.15

# %%
# Read the third stock
ma_history_csv = Path("ma_historical.csv")

ma_df = pd.read_csv(ma_history_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
ma_df.sort_index(inplace=True)
ma_df.head(3)
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  85.68
# 2015-01-05 16:00:00  83.27
# 2015-01-06 16:00:00  83.09

# %%
# Concatenate all stocks into a single DataFrame
my_combined_df = pd.concat([wmt_df, fb_df, ma_df], axis="columns", join="inner")
my_combined_df.head()
# Out:
#                      Close  Close  Close
# Date
# 2015-01-02 16:00:00  85.90  78.45  85.68
# 2015-01-05 16:00:00  85.65  77.19  83.27
# 2015-01-06 16:00:00  86.31  76.15  83.09
# 2015-01-07 16:00:00  88.60  76.15  84.22
# 2015-01-08 16:00:00  90.47  78.18  85.53

# %%
# Sort datetime index in ascending order (past to present)
my_combined_df.sort_index(inplace=True)
my_combined_df.head()
# Out:
#                      Close  Close  Close
# Date
# 2015-01-02 16:00:00  85.90  78.45  85.68
# 2015-01-05 16:00:00  85.65  77.19  83.27
# 2015-01-06 16:00:00  86.31  76.15  83.09
# 2015-01-07 16:00:00  88.60  76.15  84.22
# 2015-01-08 16:00:00  90.47  78.18  85.53

# %%
# Set column names
my_combined_df.columns = ["walmart", "facebook", "mastercard"]
my_combined_df.head()
# Out:
#                      walmart  facebook  mastercard
# Date
# 2015-01-02 16:00:00    85.90     78.45       85.68
# 2015-01-05 16:00:00    85.65     77.19       83.27
# 2015-01-06 16:00:00    86.31     76.15       83.09
# 2015-01-07 16:00:00    88.60     76.15       84.22
# 2015-01-08 16:00:00    90.47     78.18       85.53

# %%
# Count nulls
my_combined_df.isnull().sum()
# Out:
# walmart       0
# facebook      0
# mastercard    0
# dtype: int64

# %%
# Drop Nulls
my_combined_df.dropna(inplace=True)

# %%
# Use the 'pct_change' function to calculate daily returns
my_daily_returns = my_combined_df.pct_change()
my_daily_returns.head()
# Out:
#                       walmart  facebook  mastercard
# Date
# 2015-01-02 16:00:00       NaN       NaN         NaN
# 2015-01-05 16:00:00 -0.002910 -0.016061   -0.028128
# 2015-01-06 16:00:00  0.007706 -0.013473   -0.002162
# 2015-01-07 16:00:00  0.026532  0.000000    0.013600
# 2015-01-08 16:00:00  0.021106  0.026658    0.015555

# %%
# Drop Nulls
my_daily_returns.dropna(inplace=True)
my_daily_returns.head()
# Out:
#                       walmart  facebook  mastercard
# Date
# 2015-01-05 16:00:00 -0.002910 -0.016061   -0.028128
# 2015-01-06 16:00:00  0.007706 -0.013473   -0.002162
# 2015-01-07 16:00:00  0.026532  0.000000    0.013600
# 2015-01-08 16:00:00  0.021106  0.026658    0.015555
# 2015-01-09 16:00:00 -0.012380 -0.005628   -0.012744

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]

my_weighted_returns = my_daily_returns.dot(weights)
my_weighted_returns.head()
# Out:
# Date
# 2015-01-05 16:00:00   -0.015700
# 2015-01-06 16:00:00   -0.002643
# 2015-01-07 16:00:00    0.013377
# 2015-01-08 16:00:00    0.021106
# 2015-01-09 16:00:00   -0.010251
# dtype: float64

# %%
custom_portfolio = pd.DataFrame(my_weighted_returns)
custom_portfolio
# Out:
#                             0
# Date
# 2015-01-05 16:00:00 -0.015700
# 2015-01-06 16:00:00 -0.002643
# 2015-01-07 16:00:00  0.013377
# 2015-01-08 16:00:00  0.021106
# 2015-01-09 16:00:00 -0.010251
# ...                       ...
# 2019-05-23 16:00:00 -0.018514
# 2019-05-24 16:00:00  0.005337
# 2019-05-28 16:00:00  0.007756
# 2019-05-29 16:00:00 -0.004640
# 2019-05-30 16:00:00  0.002557
#
# [1108 rows x 1 columns]

# %%
custom_portfolio.reset_index(inplace=True)
custom_portfolio
# Out:
#                     Date         0
# 0    2015-01-05 16:00:00 -0.015700
# 1    2015-01-06 16:00:00 -0.002643
# 2    2015-01-07 16:00:00  0.013377
# 3    2015-01-08 16:00:00  0.021106
# 4    2015-01-09 16:00:00 -0.010251
# ...                  ...       ...
# 1103 2019-05-23 16:00:00 -0.018514
# 1104 2019-05-24 16:00:00  0.005337
# 1105 2019-05-28 16:00:00  0.007756
# 1106 2019-05-29 16:00:00 -0.004640
# 1107 2019-05-30 16:00:00  0.002557
#
# [1108 rows x 2 columns]

# %%
# Keeping only date from datetime
custom_portfolio["Date"] = custom_portfolio["Date"].dt.date
custom_portfolio.head()
# Out:
#          Date         0
# 0  2015-01-05 -0.015700
# 1  2015-01-06 -0.002643
# 2  2015-01-07  0.013377
# 3  2015-01-08  0.021106
# 4  2015-01-09 -0.010251

# %%
# Setting index into Date column and converting the dates to a DateTimeIndex
custom_portfolio.set_index(custom_portfolio['Date'], inplace=True)
custom_portfolio.head(3)
# Out:
#                   Date         0
# Date
# 2015-01-05  2015-01-05 -0.015700
# 2015-01-06  2015-01-06 -0.002643
# 2015-01-07  2015-01-07  0.013377

# %%
# Drop extra column
custom_portfolio.drop(columns=['Date'], inplace=True)
custom_portfolio.head(3)
# Out:
#                    0
# Date
# 2015-01-05 -0.015700
# 2015-01-06 -0.002643
# 2015-01-07  0.013377

# %%
custom_portfolio.columns
# Out:
# Index([0], dtype='object')

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
all_of_returns = combined_df.copy()
all_of_returns.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196

# %%
all_the_returns = pd.concat([all_of_returns, custom_portfolio], axis = "columns", join="inner")
all_the_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500         0
# Date
# 2015-03-03 -0.000949 -0.004539 -0.006773
# 2015-03-04  0.002416 -0.004389  0.004997
# ...

# %%
all_the_returns.columns
# Out:
# Index([  'SOROS FUND MANAGEMENT LLC',          'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC',      'BERKSHIRE HATHAWAY INC',
#                             'Algo 1',                      'Algo 2',
#                            'S&P 500',                             0],
#       dtype='object')

# %%
# Trying to rename the column name but it does not change, so I will just keep as "0" for my portfolio column name
df_new = all_the_returns.rename(columns={'0': 'Custom'})
df_new
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
all_the_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# 0                              0
# dtype: int64

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_the_returns.dropna(inplace = True)
all_the_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500         0
# Date
# 2015-03-03 -0.000949 -0.004539 -0.006773
# 2015-03-04  0.002416 -0.004389  0.004997
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
volatility_all = all_the_returns.std() * np.sqrt(252)
volatility_all
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# 0                              0.176530
# dtype: float64

# %%
volatility_all > volatility_all["S&P 500"]
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# 0                               True
# dtype: bool

# %% [markdown]
# - Answer: My portfolio is riskier than the market based on above volatility.

# %%
# Rolling
rolling_std = all_the_returns.rolling(window=21).std()
rolling_std.plot(figsize = (20, 7))

# %%
# Annualized Sharpe Ratios
mean_all = all_the_returns.mean() * 252
std_all = all_the_returns.std() * np.sqrt(252)
sharpe_ratios_all = mean_all / std_all
sharpe_ratios_all
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# 0                              1.079989
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_all.plot.bar()

# %% [markdown]
# - Answer: My porfolios("0" in the above plot) perform better than other portfolios and the market(S&P 500) except the Algo 1.

# %%
# Create a correlation analysis
correlation_all = all_the_returns.corr()
correlation_all
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
# 0                                             0.670454            0.494031
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# ...

# %%
all_the_returns.columns
# Out:
# Index([  'SOROS FUND MANAGEMENT LLC',          'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC',      'BERKSHIRE HATHAWAY INC',
#                             'Algo 1',                      'Algo 2',
#                            'S&P 500',                             0],
#       dtype='object')

# %%
# Selecting the last column which is my custom portfolio to be able to calculate the Beta in the below cell, due to being unable to rename the column "0"
all_the_returns.iloc[:,-1:]
# Out:
#                    0
# Date
# 2015-03-03 -0.006773
# 2015-03-04  0.004997
# 2015-03-05  0.009272
# 2015-03-06 -0.016089
# 2015-03-09  0.000007
# ...              ...
# 2019-04-16  0.001490
# 2019-04-17  0.001841
# 2019-04-18 -0.001020
# 2019-04-22  0.006280
# 2019-04-23  0.007182
#
# [1043 rows x 1 columns]

# %%
# Beta
covariance_all = all_the_returns.iloc[:, -1].rolling(window=60).cov(all_the_returns["S&P 500"])
variance_all = all_the_returns["S&P 500"].rolling(window=60).var()
beta_all = covariance_all / variance_all
beta_all.plot(figsize = (20, 7))

# %% [markdown]
# - As I couldn't rename the column "0" into "Custom" as described above, I selected the last column of dataframe using iloc, and then calculated beta and plotted it above. Feedback for renaming this "0" into "Custom" would be appreciated!

# %% [markdown]
# - "Beta is a measure of a stock's volatility in relation to the overall market.
# By definition, the market, such as the S&P 500 Index, has a beta of 1.0, and individual stocks are ranked according
# to how much they deviate from the market.
# A stock that swings more than the market over time has a beta above 1.0. If a stock moves less than the market,
# the stock's beta is less than 1.0. High-beta stocks are supposed to be riskier
# but provide higher return potential; low-beta stocks pose less risk but also lower returns." - investopedia.com
# <br>
# Based on the plot above and the definition of Beta from investopedia.com tells me that my porfolios are overall riskier
# than the market, but provide higher return potential.
